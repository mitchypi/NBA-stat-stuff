# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Raptor Data From:
#
# https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-raptor/modern_RAPTOR_by_player.csv

# %%
salaryRaptor = pd.read_csv('salaryRaptor1.csv')

# %%
salaryRaptor
# Out:
#                    Player         Salary  Raptor
# 0           Stephen Curry  43,006,362.00     7.0
# 1       Russell Westbrook  41,358,814.00    -2.3
# 2              Chris Paul  41,358,814.00     3.0
# 3               John Wall  41,254,920.00    -2.3
# 4            James Harden  40,824,000.00     4.4
# 5            LeBron James  39,219,565.00     5.6
# 6            Kevin Durant  39,058,950.00     5.8
# 7             Paul George  35,450,412.00     7.1
# 8           Klay Thompson  35,361,360.00    -0.2
# 9             Mike Conley  34,504,132.00     7.7
# 10           Jimmy Butler  34,379,100.00     7.3
# 11           Kemba Walker  34,379,100.00     4.1
# 12          Kawhi Leonard  34,379,100.00     8.1
# 13          Tobias Harris  33,517,241.00     2.3
# 14           Kyrie Irving  33,329,100.00     2.4
# 15        Khris Middleton  33,051,724.00     1.4
# 16          Anthony Davis  32,742,000.00     3.4
# 17          Blake Griffin  33,685,241.00     1.8
# ...

# %%
salaryRaptor.plot.scatter(x="Salary",y="Raptor",yticks=range(-5,10))
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Raptor'>
